# %% [markdown]
# # Agent Loan Decisioning

# %%
import datetime
from datetime import date,timedelta
import numpy as np
import pandas as pd
import camelot
import matplotlib.pyplot as plt

# %% [markdown]
# Qualifying Matrix
#
# 1.	Agent Length on Service - 3 months
#
# 2.	Agent Frequency of use/activity - >= 65 transactions(count) in total
#
# 3.	Agent Frequency of rebalance - >= 45 inbound(count) in total
#
# 4.	Median Cash-In for last 90 days - avg. txn amnt - ghs5000
#
# 5.	Mode Cash-In for last 90 days - lowest amnt cash in - ghs1000
#
# 6.	Median Cash-Out for last 90 days - avg. txn amnt - ghs5000
#
# 7.	Mode Cash-Out for last 90 days - lowest amnt cash out - ghs1000

# %%
## Have not merged with entire script flow

##### full pdf reading

tables = camelot.read_pdf(r'C:\Users\Chakdahah\MomoStatementReport.pdf',pages='all')
# tables = camelot.read_pdf(r'C:\Users\Chakdahah\MomoStatement2.pdf',pages='all')
tables



# tables[j].parsing_report #check parsing report to see accuracy of parsing and other details

# append to one csv file

table_fin = tables[0].df #convert first table to df and assign to variable 

for i in range(1,len(tables)-1): # skip 0-nth of tables
    print(i)
    t = tables[i].df 
    t.drop(t.index[0], inplace = True) # drop first row of df
    table_fin = pd.concat([table_fin, t], axis = 0)
    

    print(t)
# Out:
# 1
#                          0         1                 2             3   \
# 1   24-Jan-2022 11:01:15 AM  39011174      sdpnsanopull             0
# 2   23-Jan-2022 02:02:12 PM  43122976  Emmanuel Lamptey  233244471083
# 3   22-Jan-2022 12:54:51 PM  39011174      sdpnsanopull             0
# 4   22-Jan-2022 09:13:37 AM  43122976  Emmanuel Lamptey  233244471083
# 5   22-Jan-2022 08:57:27 AM  55669221    George Lamptey  233559692902
# 6   21-Jan-2022 11:09:01 PM  43122976  Emmanuel Lamptey  233244471083
# 7   21-Jan-2022 08:29:23 PM  43122976  Emmanuel Lamptey  233244471083
# 8   21-Jan-2022 04:44:28 PM  43122976  Emmanuel Lamptey  233244471083
# 9   20-Jan-2022 08:53:19 AM  43122976  Emmanuel Lamptey  233244471083
# 10  20-Jan-2022 08:47:44 AM  43122976  Emmanuel Lamptey  233244471083
# 11  18-Jan-2022 10:41:41 AM  43122976  Emmanuel Lamptey  233244471083
# 12  17-Jan-2022 06:02:26 PM  43122976  Emmanuel Lamptey  233244471083
# 13  16-Jan-2022 10:14:19 PM  43122976  Emmanuel Lamptey  233244471083
# 14  14-Jan-2022 09:43:35 AM  39011174      sdpnsanopull             0
# 15  13-Jan-2022 05:41:04 PM  43122976  Emmanuel Lamptey  233244471083
#
#           4     5    6        7        8             9   \
# 1   TRANSFER   350    0  2038.06  2388.06  233244471083
# 2   TRANSFER    65    0  2103.06  2038.06  233245993313
# 3   TRANSFER  1100    0  1003.06  2103.06  233244471083
# 4   CASH_OUT   600    6  1609.06  1003.06  233546217351
# 5   TRANSFER   300    3  1309.06  1609.06  233244471083
# 6   TRANSFER   200    2  1511.06  1309.06  233545596599
# 7      DEBIT    10    0  1521.06  1511.06             0
# 8   TRANSFER    81    0  1602.06  1521.06  233243831426
# 9      DEBIT    10    0  1612.06  1602.06             0
# 10     DEBIT    10    0  1622.06  1612.06             0
# 3         Emmanuel \nLamptey  43122976  14706138634
# 4         Emmanuel \nLamptey  43122976  14699164308
# 5             MonicaA. Ayesu  42393435  14685137009
# 6         Emmanuel \nLamptey  43122976  14684928840
# 7   MTNONLINEAIRTI\nMEVENDOR  39011161  14477539564
# 8                     cisnew  62525623  14477536408
# 9         Emmanuel \nLamptey  43122976  14477530332
# 10        DANIEL  \nKUMORDZI  59685953  14404966268
# 11        Emmanuel \nLamptey  43122976  14404946197
# 12        Emmanuel \nLamptey  43122976  14367940808
# 13                       cis  53169694  14300156810
#
#                                                    13  \
# 1                                     Internet Bundle
# 2      Ghana \nTelecommunicatio\nns Company \nLimited
# 3
# 4
# 5                                                   1
# 6
# 7
# 8                                     Internet Bundle
# 9   Lamptey \nEmmanuel ,23350\n0293173,null from \...
# 10                                   Passport-2989491
# 11  Lamptey \nEmmanuel ,23350\n0293173,null from \...
# 12
# 13                                    Internet Bundle
#
#                           14
# 1                        cis
# 2                  blupen.sp
# 3                   Internal
# 4                   Internal
# 5                   Internal
# 6                   Internal
# 7   MTNONLINEAIRTIMEVEND\nOR
# 8                     cisnew
# 9                   Internal
# 10                  Internal
# 11                  Internal
# 12                  Internal
# 13                       cis
# 6
#                         0         1                            2   \
# 1  09-Oct-2021 04:51:52 PM  54814562  INTEROPERABILITY \nPULL OVA
# 2  04-Oct-2021 06:25:47 PM  43122976             Emmanuel Lamptey
# 3  04-Oct-2021 06:13:19 PM  43122976             Emmanuel Lamptey
# 4  04-Oct-2021 04:20:42 PM  54814562  INTEROPERABILITY \nPULL OVA
# 5  01-Oct-2021 09:20:43 AM  43122976             Emmanuel Lamptey
# 6  01-Oct-2021 09:19:02 AM  57027303                DZOBOKU  AMOS
# 7  01-Oct-2021 08:13:49 AM  39011174                 sdpnsanopull
#
#              3         4    5    6       7       8             9   \
# 1  233243868227  TRANSFER   10    0    0.82   10.82  233244471083
# 2  233244471083     DEBIT   10    0   10.82    0.82             0
# 3  233244471083     DEBIT  240    0  250.82   10.82  233547169801
# 4  233243868227  TRANSFER  250    0    0.82  250.82  233244471083
# 5  233244471083  TRANSFER  710  7.1  717.92    0.82  233246445697
# 6  233243547350   CASH_IN  405    0  312.92  717.92  233244471083
# 7             0  TRANSFER   50    0  262.92  312.92  233244471083
#
#                    10        11           12  \
# 1  Emmanuel \nLamptey  43122976  14300097665
# 2                 cis  53169694  14234957676
# 3              BluPay  57781322  14234686812
# 4  Emmanuel \nLamptey  43122976  14232443471
# 5    Margeret Simmons  40276890  14186714431
# 6  Emmanuel \nLamptey  43122976  14186688160
# 7  Emmanuel \nLamptey  43122976  14185716626
#
#                                                   13         14
# 1  Lamptey \nEmmanuel ,23350\n0293173,null from \...   Internal
# 2                                    Internet Bundle        cis
# 3     Ghana \nTelecommunicatio\nns Company \nLimited  blupen.sp
# 4  ZEEPAY \nGHANA ,23xxxxxx\n73,FTC-622897 \nfrom...   Internal
# 5                                                  1   Internal
# 6                           Cashin To-\n233244471083   Internal
# 7                                                      Internal

# %%
momo_data = table_fin
momo_data
# Out:
#                          0          1                            2   \
# 0          TRANSACTION DATE  FROM ACCT                    FROM NAME
# 1   31-Jan-2022 04:12:32 PM   43122976             Emmanuel Lamptey
# 2   31-Jan-2022 11:53:00 AM   43122976             Emmanuel Lamptey
# 3   28-Jan-2022 01:51:50 PM   43122976             Emmanuel Lamptey
# 4   27-Jan-2022 02:55:21 PM   43122976             Emmanuel Lamptey
# ..                      ...        ...                          ...
# 3   04-Oct-2021 06:13:19 PM   43122976             Emmanuel Lamptey
# 4   04-Oct-2021 04:20:42 PM   54814562  INTEROPERABILITY \nPULL OVA
# 5   01-Oct-2021 09:20:43 AM   43122976             Emmanuel Lamptey
# 6   01-Oct-2021 09:19:02 AM   57027303                DZOBOKU  AMOS
# 7   01-Oct-2021 08:13:49 AM   39011174                 sdpnsanopull
#
#               3            4       5     6           7          8   \
# 0       FROM NO.  TRANS. TYPE  AMOUNT  FEES  BAL BEFORE  BAL AFTER
# 1   233244471083      PAYMENT      40   0.5     1741.08    1700.58
# 2   233244471083        DEBIT      10     0     1751.08    1741.08
# 3   233244471083     TRANSFER      20     0     1771.08    1751.08
# 4   233244471083     TRANSFER    1680    10     3461.08    1771.08
# ..           ...          ...     ...   ...         ...        ...
# 3   233244471083        DEBIT     240     0      250.82      10.82
# 4   233243868227     TRANSFER     250     0        0.82     250.82
# 5   233244471083     TRANSFER     710   7.1      717.92       0.82
# 6   233243547350      CASH_IN     405     0      312.92     717.92
# 7              0     TRANSFER      50     0      262.92     312.92
#
#               9                             10        11           12  \
# 0         TO NO.                       TO NAME   TO ACCT         F_ID
# 1   233243868392  INTEROPERABILIT\nY PUSH  OVA  54814522  15865181460
# 2              0                           cis  53169694  15861507663
# 3   233552384736                  nancy akuffo  53815211  15824193330
# 4   233557938985                PATRICIA ANNOR  52297015  15810636337
# ..           ...                           ...       ...          ...
# 3   233547169801                        BluPay  57781322  14234686812
# 4   233244471083            Emmanuel \nLamptey  43122976  14232443471
# 5   233246445697              Margeret Simmons  40276890  14186714431
# 6   233244471083            Emmanuel \nLamptey  43122976  14186688160
# 7   233244471083            Emmanuel \nLamptey  43122976  14185716626
#
#                                                    13         14
# 0                                                 REF        OVA
# 1                  Prince \nAbroquah,2332082\n09124,1    mmipush
# 2                                     Internet Bundle        cis
# 3                                                   1   Internal
# 4                                                   1   Internal
# ..                                                ...        ...
# 3      Ghana \nTelecommunicatio\nns Company \nLimited  blupen.sp
# 4   ZEEPAY \nGHANA ,23xxxxxx\n73,FTC-622897 \nfrom...   Internal
# 5                                                   1   Internal
# 6                            Cashin To-\n233244471083   Internal
# 7                                                       Internal
#
# [90 rows x 15 columns]

# %%
momo_data.columns = momo_data.iloc[0] #set column names equal to values in row index position 0
momo_data = momo_data[1:] # remove first row from DataFrame

# %%
momo_data.reset_index(drop=True, inplace=True)

# %%
momo_data
# Out:
# 0          TRANSACTION DATE FROM ACCT                          FROM NAME  \
# 0   31-Jan-2022 04:12:32 PM  43122976                   Emmanuel Lamptey
# 1   31-Jan-2022 11:53:00 AM  43122976                   Emmanuel Lamptey
# 2   28-Jan-2022 01:51:50 PM  43122976                   Emmanuel Lamptey
# 3   27-Jan-2022 02:55:21 PM  43122976                   Emmanuel Lamptey
# 4   27-Jan-2022 02:53:50 PM  53104390  FIDELITY BANK LTD \nBREKUM BRANCH
# ..                      ...       ...                                ...
# 84  04-Oct-2021 06:13:19 PM  43122976                   Emmanuel Lamptey
# 85  04-Oct-2021 04:20:42 PM  54814562        INTEROPERABILITY \nPULL OVA
# 86  01-Oct-2021 09:20:43 AM  43122976                   Emmanuel Lamptey
# 87  01-Oct-2021 09:19:02 AM  57027303                      DZOBOKU  AMOS
# 88  01-Oct-2021 08:13:49 AM  39011174                       sdpnsanopull
#
# 0       FROM NO. TRANS. TYPE AMOUNT FEES BAL BEFORE BAL AFTER        TO NO.  \
# 0   233244471083     PAYMENT     40  0.5    1741.08   1700.58  233243868392
# 1   233244471083       DEBIT     10    0    1751.08   1741.08             0
# 2   233244471083    TRANSFER     20    0    1771.08   1751.08  233552384736
# 3   233244471083    TRANSFER   1680   10    3461.08   1771.08  233557938985
# 4   233549293662     CASH_IN   1690    0    1771.08   3461.08  233244471083
# ..           ...         ...    ...  ...        ...       ...           ...
# 84  233244471083       DEBIT    240    0     250.82     10.82  233547169801
# 85  233243868227    TRANSFER    250    0       0.82    250.82  233244471083
# 86  233244471083    TRANSFER    710  7.1     717.92      0.82  233246445697
# 87  233243547350     CASH_IN    405    0     312.92    717.92  233244471083
# 88             0    TRANSFER     50    0     262.92    312.92  233244471083
#
# 0                        TO NAME   TO ACCT         F_ID  \
# 0   INTEROPERABILIT\nY PUSH  OVA  54814522  15865181460
# 1                            cis  53169694  15861507663
# 2                   nancy akuffo  53815211  15824193330
# 3                 PATRICIA ANNOR  52297015  15810636337
# 4             Emmanuel \nLamptey  43122976  15810617557
# ..                           ...       ...          ...
# 84                        BluPay  57781322  14234686812
# 85            Emmanuel \nLamptey  43122976  14232443471
# 86              Margeret Simmons  40276890  14186714431
# 87            Emmanuel \nLamptey  43122976  14186688160
# 88            Emmanuel \nLamptey  43122976  14185716626
#
# 0                                                 REF        OVA
# 0                  Prince \nAbroquah,2332082\n09124,1    mmipush
# 1                                     Internet Bundle        cis
# 2                                                   1   Internal
# 3                                                   1   Internal
# 4                                                       Internal
# ..                                                ...        ...
# 84     Ghana \nTelecommunicatio\nns Company \nLimited  blupen.sp
# 85  ZEEPAY \nGHANA ,23xxxxxx\n73,FTC-622897 \nfrom...   Internal
# 86                                                  1   Internal
# 87                           Cashin To-\n233244471083   Internal
# 88                                                      Internal
#
# [89 rows x 15 columns]

# %%
#Reading data from csv file

# momo_data = pd.read_csv(r'\Users\Chakdahah\Cleaned_Momo.csv', skipinitialspace = True)

# Clean whitespaces in colunn name and entire dataframe

momo_data =momo_data.rename(columns=lambda x: x.strip())
momo_data =momo_data.applymap(lambda x: x.strip() if isinstance(x, str) else x)

momo_data.head()
# Out:
# 0         TRANSACTION DATE FROM ACCT                          FROM NAME  \
# 0  31-Jan-2022 04:12:32 PM  43122976                   Emmanuel Lamptey
# 1  31-Jan-2022 11:53:00 AM  43122976                   Emmanuel Lamptey
# 2  28-Jan-2022 01:51:50 PM  43122976                   Emmanuel Lamptey
# 3  27-Jan-2022 02:55:21 PM  43122976                   Emmanuel Lamptey
# 4  27-Jan-2022 02:53:50 PM  53104390  FIDELITY BANK LTD \nBREKUM BRANCH
#
# 0      FROM NO. TRANS. TYPE AMOUNT FEES BAL BEFORE BAL AFTER        TO NO.  \
# 0  233244471083     PAYMENT     40  0.5    1741.08   1700.58  233243868392
# 1  233244471083       DEBIT     10    0    1751.08   1741.08             0
# 2  233244471083    TRANSFER     20    0    1771.08   1751.08  233552384736
# 3  233244471083    TRANSFER   1680   10    3461.08   1771.08  233557938985
# 4  233549293662     CASH_IN   1690    0    1771.08   3461.08  233244471083
#
# 0                       TO NAME   TO ACCT         F_ID  \
# 0  INTEROPERABILIT\nY PUSH  OVA  54814522  15865181460
# 1                           cis  53169694  15861507663
# 2                  nancy akuffo  53815211  15824193330
# 3                PATRICIA ANNOR  52297015  15810636337
# 4            Emmanuel \nLamptey  43122976  15810617557
#
# 0                                 REF       OVA
# 0  Prince \nAbroquah,2332082\n09124,1   mmipush
# 1                     Internet Bundle       cis
# 2                                   1  Internal
# 3                                   1  Internal
# 4                                      Internal

# %%
# remove unwanted characters from end of column names
# mmomo_data.rename(columns=lambda x: x.strip('.'),inplace =True)

# remove all unwanted characters in column names
momo_data.rename(columns=lambda s: s.replace(".", ""), inplace=True)

# replace whitespaces with underscore
momo_data.rename(columns=lambda s: s.replace(" ", "_"), inplace=True)

# %%
import sys
sys.maxsize
# 2147483647
# Out:
# 9223372036854775807

# %%
momo_data['TO_ACCT'] = pd.Series(momo_data['TO_ACCT'], dtype=np.float64)

# %%
>>> preds = np.zeros((1, 3))

# %%
# cast appropriate data types
# momo_data['TRANSACTION_DATE'] = momo_data['TRANSACTION_DATE'].astype(datetime)

# momo_data['TRANSACTION_DATE'] = pd.to_datetime(momo_data['TRANSACTION_DATE'])
momo_data['FROM_NO'] = momo_data['FROM_NO'].astype('float')
momo_data['AMOUNT'] = momo_data['AMOUNT'].astype('float')
momo_data['FEES'] = momo_data['FEES'].astype('float')
momo_data['BAL_BEFORE'] = momo_data['BAL_BEFORE'].astype('float')
momo_data['BAL_AFTER'] = momo_data['BAL_AFTER'].astype('float')
momo_data['TO_NO'] = momo_data['TO_NO'].astype('float')
momo_data['F_ID'] = momo_data['F_ID'].astype('float')


# df['Integer'] = df['Profit'].astype('int')

# %%
#Suppressing any scientific notation in entire csv file.

pd.set_option('display.float_format', lambda x: '%.0f' % x)

# %%
momo_data.head()
# Out:
# 0         TRANSACTION_DATE FROM_ACCT                          FROM_NAME  \
# 0  31-Jan-2022 04:12:32 PM  43122976                   Emmanuel Lamptey
# 1  31-Jan-2022 11:53:00 AM  43122976                   Emmanuel Lamptey
# 2  28-Jan-2022 01:51:50 PM  43122976                   Emmanuel Lamptey
# 3  27-Jan-2022 02:55:21 PM  43122976                   Emmanuel Lamptey
# 4  27-Jan-2022 02:53:50 PM  53104390  FIDELITY BANK LTD \nBREKUM BRANCH
#
# 0      FROM_NO TRANS_TYPE  AMOUNT  FEES  BAL_BEFORE  BAL_AFTER        TO_NO  \
# 0 233244471083    PAYMENT      40     0        1741       1701 233243868392
# 1 233244471083      DEBIT      10     0        1751       1741            0
# 2 233244471083   TRANSFER      20     0        1771       1751 233552384736
# 3 233244471083   TRANSFER    1680    10        3461       1771 233557938985
# 4 233549293662    CASH_IN    1690     0        1771       3461 233244471083
#
# 0                       TO_NAME   TO_ACCT        F_ID  \
# 0  INTEROPERABILIT\nY PUSH  OVA  54814522 15865181460
# 1                           cis  53169694 15861507663
# 2                  nancy akuffo  53815211 15824193330
# 3                PATRICIA ANNOR  52297015 15810636337
# 4            Emmanuel \nLamptey  43122976 15810617557
#
# 0                                 REF       OVA
# 0  Prince \nAbroquah,2332082\n09124,1   mmipush
# 1                     Internet Bundle       cis
# 2                                   1  Internal
# 3                                   1  Internal
# 4                                      Internal

# %%
momo_data.info(all)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   TRANSACTION_DATE  89 non-null     object
#  1   FROM_ACCT         89 non-null     object
#  2   FROM_NAME         89 non-null     object
#  3   FROM_NO           89 non-null     float64
#  4   TRANS_TYPE        89 non-null     object
#  5   AMOUNT            89 non-null     float64
#  6   FEES              89 non-null     float64
#  7   BAL_BEFORE        89 non-null     float64
#  8   BAL_AFTER         89 non-null     float64
#  9   TO_NO             89 non-null     float64
#  10  TO_NAME           89 non-null     object
#  11  TO_ACCT           89 non-null     object
#  12  F_ID              89 non-null     float64
#  13  REF               89 non-null     object
#  14  OVA               89 non-null     object
# dtypes: float64(7), object(8)
# memory usage: 10.6+ KB

# %%
## convert momo_data to csv
momo_data.to_csv("StrippedMomotoCSV")
momo_data.to_excel("StrippedMomotoXLS.xlsx")

# %%
# Set empty list and dict
masterData = []
userData= {}

# %% [markdown]
# # Calculation of scoring parameters

# %%
rows = momo_data.count()[0] # Agent Frequency of use
userData["freq_of_active"] = rows



MOMO=momo_data[(momo_data == 'CASH_IN').any(axis=1)] # frequency of rebalance
MOMOR = MOMO.count()[0]
userData["freq_of_repl"] = MOMOR



meadnie = momo_data.loc[momo_data['TRANS_TYPE']=='CASH_IN','AMOUNT'].median() #Median Cash-In for last 90days
# userData["mead_cash_in"] = meadnie
# userData["mead_cash_in"]
userData["mead_cash_in_calc"] = meadnie*4


modnie = momo_data.loc[momo_data['TRANS_TYPE']=='CASH_IN','AMOUNT'].mode() # Mode Cash-In for last 90 days
userData["modnie_cash_in_calc"] = modnie*4
userData["modnie_cash_in_calc"] = userData["modnie_cash_in_calc"]*4
userData["modnie_cash_in_calc"] = max(userData["modnie_cash_in_calc"])


meadniout = momo_data.loc[momo_data['TRANS_TYPE']=='CASH_OUT','AMOUNT'].median() # Median Cash-Out for last 90 days
# userData["mead_cash_out"] = meadniout
# userData["mead_cash_out"]
userData["mead_cash_out_calc"] = meadniout*4


modno = momo_data.loc[momo_data['TRANS_TYPE']=='CASH_OUT','AMOUNT'].mode() # Mode Cash-Out for last 90 days
userData["modno_cash_out_calc"] = modno*4 
userData["modno_cash_out_calc"] = userData["modno_cash_out_calc"]*4
userData["modno_cash_out_calc"] = max(userData["modno_cash_out_calc"])

# %% [markdown]
# # Scoring Criteria Calculation

# %%
user_copy = userData.copy()
masterData.append(user_copy)

# %%
### scoring

inelligible = []
elligible = []

# %%
type(userData["modnie_cash_in_calc"])
# Out:
# float

# %%
Credit_score = 100


for index in range(len(masterData)):

    ## Frequency of use  >= 65 transactions(count) in total

    if masterData[index]["freq_of_active"]> 65 and masterData[index]["freq_of_active"] <= 75:
        user_copy = masterData[index]
#         print(user_copy)
        Credit_score += 50 
    elif masterData[index]["freq_of_active"]> 75:
        elig_copy = masterData[index]
        Credit_score+= 100

        
        
#Agent Frequency of rebalance - >= 45 inbound(count) in total

    if masterData[index]["freq_of_repl"]>= 45 and masterData[index]["freq_of_repl"] <= 54:
        user_copy = masterData[index]
        Credit_score += 50 
    elif masterData[index]["freq_of_active"]> 54:
        elig_copy = masterData[index]
        Credit_score+= 100

        
        
        # Median Cash-In for last 90 days - avg. txn amnt - ghs5000 

        
    if masterData[index]["mead_cash_in_calc"] >= 5000:
        user_copy = masterData[index]
        Credit_score += 50
        
    else:
        Credit_score+= 0

        
        
          # Mode Cash-In for last 90 days - lowest amnt cash in - ghs1000 

        
    if masterData[index]["modnie_cash_in_calc"] >= 1000:
        user_copy = masterData[index]
        Credit_score += 50 
        
    else:
        elig_copy = masterData[index]
        Credit_score+= 0
        
        
        
       # Median Cash-Out for last 90 days - avg. txn amnt - ghs5000


    if masterData[index]["mead_cash_out_calc"] > 5000:
        user_copy = masterData[index]
        Credit_score += 50 
        
    else:
        elig_copy = masterData[index]
        Credit_score+= 0
        
#     Mode Cash-Out for last 90 days - lowest amnt cash out - ghs1000 
        
    if masterData[index]["modno_cash_out_calc"] >= 1000:
        user_copy = masterData[index]
        Credit_score += 50 
        
    else:
        elig_copy = masterData[index]
        Credit_score+= 0     
    

#         print(elig_copy)
elligible.append(elig_copy)
        
        
        
        
print("Inelligble", inelligible)
print('\n')
print("Elligible", elligible)
# Out:
# Inelligble []
#
#
# Elligible [{'freq_of_active': 89, 'freq_of_repl': 2, 'mead_cash_in_calc': 4190.0, 'modnie_cash_in_calc': 27040.0, 'mead_cash_out_calc': 2000.0, 'modno_cash_out_calc': 9600.0}]

# %%
type(elligible)
# Out:
# list

# %%
### convert dict to df

pd.DataFrame.from_dict(elligible)
# Out:
#    freq_of_active  freq_of_repl  mead_cash_in_calc  modnie_cash_in_calc  \
# 0              89             2               4190                27040
#
#    mead_cash_out_calc  modno_cash_out_calc
# 0                2000                 9600

# %%
Credit_score
# Out:
# 400

# %% [markdown]
# # Applying scores to Merchants

# %%
    
    if Credit_score >= 200 and Credit_score <= 250:
        print("You qualify for a GHS 1000 loan")

    elif Credit_score >= 251 and Credit_score <= 350:
        print("You qualify for a GHS 2000 loan")

    elif Credit_score >= 351 and Credit_score <= 400:
        print("You qualify for a GHS 3000 loan")

    elif Credit_score >= 401 and Credit_score <= 500:
        print("You qualify for a GHS 5000 loan")
# Out:
# You qualify for a GHS 3000 loan

# %% [markdown]
# # Score and risk grade table

# %%
details = {
    'Risk Ranking' : ['RR-1', 'RR-2', 'RR-3', 'RR-4'],
    'Minimum Score' : [200,251,351,401],
    'Maximum Score' : [250,350,400,500],
    'Qualifying Amount(GHS)':[1000,2000,3000,5000]
}
  
# creating a Dataframe object 
df = pd.DataFrame(details)
df
# Out:
#   Risk Ranking  Minimum Score  Maximum Score  Qualifying Amount(GHS)
# 0         RR-1            200            250                    1000
# 1         RR-2            251            350                    2000
# 2         RR-3            351            400                    3000
# 3         RR-4            401            500                    5000
